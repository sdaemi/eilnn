# %%
import eilnn
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log
from samples import particles
import sys
import cc3d

# %%
config = particles.ParticlesConfig()
subset = 'pristine_abs'
ROOT_DIR = os.path.abspath('C:/Users/Sohrab/Documents/crack/EILNet_tf2/')
sys.path.append(ROOT_DIR)
PARTICLE_DIR = os.path.join(ROOT_DIR, 'images',subset)
COCO_MODEL_PATH = 'C:/Users/Sohrab/Documents/crack/EILNet/mask_rcnn_coco.h5'

class InferenceConfig(config.__class__):
    GPU_COUNT = 1
    IMAGES_PER_GPU =1
    IMAGE_RESIZE_MODE = 'square'
    IMAGE_MIN_DIM = 768
    IMAGE_MAX_DIM = 1024
    LEARNING_RATE = 0.0001
    LEARNING_MOMENTUM = 0.9
    USE_MINI_MASK = False
    BATCH_SIZE=1
    VALIDATION_STEPS = 100
    NUM_CLASSES = 2
    
config_inference= InferenceConfig()
DEVICE = '/GPU:0'
TEST_MODE = 'inference'
def get_ax(rows=1, cols=1, size=16):
    _, ax = plt.subplots(rows,cols,figsize=(size*cols,size*rows))
    return ax
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25349874bd08> in <module>
# ----> 1 config = particles.ParticlesConfig()
#       2 subset = 'pristine_abs'
#       3 ROOT_DIR = os.path.abspath('C:/Users/Sohrab/Documents/crack/EILNet_tf2/')
#       4 sys.path.append(ROOT_DIR)
#       5 PARTICLE_DIR = os.path.join(ROOT_DIR, 'images',subset)
#
# NameError: name 'particles' is not defined

# %%
with tf.device(DEVICE):
    #changelogs
    model = modellib.MaskRCNN(mode='inference', config = config_inference, model_dir = 'C:/Users/Sohrab/Documents/crack/EILNet_tf2/logs')
model.load_weights(os.path.join(ROOT_DIR, 'C:/Users/Sohrab/Documents/crack/EILNet_tf2/logs/particles20220401T1334/mask_rcnn_particles_0450.h5'), by_name=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-14940d47eb80> in <module>
# ----> 1 with tf.device(DEVICE):
#       2     #changelogs
#       3     model = modellib.MaskRCNN(mode='inference', config = config_inference, model_dir = 'C:/Users/Sohrab/Documents/crack/EILNet_tf2/logs')
#       4 model.load_weights(os.path.join(ROOT_DIR, 'C:/Users/Sohrab/Documents/crack/EILNet_tf2/logs/particles20220401T1334/mask_rcnn_particles_0450.h5'), by_name=True)
#
# NameError: name 'tf' is not defined

# %%
##### segm = eilnn.Segment_3D(model, os.path.join(eilnn.IMAGES_DIR, 'test_gray_slices'), 2)
segm = eilnn.Segment_3D(model,PARTICLE_DIR, 8)
# Out:
# Loading images in: C:\Users\Sohrab\Documents\crack\EILNet_tf2\images\pristine_abs
# Stack Dimensions  (1020, 1024, 1008, 3)

# %%
particles, masks, background_val, watershed = segm.process_segm()
# Out:
# grayscale(1020, 1024, 1008, 3)
# label(1020, 1024, 1008)
# Done Distance Transform
# Done Extended Minima
# (1020, 1024, 1008, 3)
# (1020, 1024, 1008)
# Segmentation took 106.0 minutes

# %%
for i in range(0, label_field.shape[0]):
    filename = "label_" + str(i) + ".tiff"
    save_path = os.path.join(out_dir, filename)
    cv2.imwrite(save_path, label_field_export[i, :, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-601fea48075e> in <module>
# ----> 1 for i in range(0, label_field.shape[0]):
#       2     filename = "label_" + str(i) + ".tiff"
#       3     save_path = os.path.join(out_dir, filename)
#       4     cv2.imwrite(save_path, label_field_export[i, :, :])
#
# NameError: name 'label_field' is not defined

# %%
print(particles[1].shape)
# Out:
# (5, 70, 80, 3)

# %%
grayscale_stack = eilnn.load_grayscale(os.path.join(eilnn.IMAGES_DIR, 'test_gray_slices'))

# %%
eilnn.save_pickles(particles, 'particles_s25_x.txt')
# Out:
# Saving particles_s13_x.txt

# %%
eilnn.save_pickles(masks, 'masks_s13_x.txt')
# Out:
# Saving masks_s13_x.txt

# %%
eilnn.save_label(watershed, 's25_watershed')
# Out:
# Saving labels in s25_watershed

# %%
print(background_val)
# Out:
# 75

# %%
plt.imshow(watershed[50,:,:])

# %%
segmentation_2d = segm.segment_2d(model, grayscale_stack)
# Out:
# Segmentation took 0.2 minutes

# %%
print(segmentation_2d.shape)
# Out:
# (1024, 1004, 20)
